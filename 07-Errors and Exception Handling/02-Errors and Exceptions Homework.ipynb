# %% [markdown]
# # Errors and Exceptions Homework

# %% [markdown]
# ### Problem 1
# Handle the exception thrown by the code below by using <code>try</code> and <code>except</code> blocks.

# %%
try:
    for i in ['a','b','c']:
        print(i**2)
except:
    print("Please give the list of integers instead of string")

# %% [markdown]
# ### Problem 2
# Handle the exception thrown by the code below by using <code>try</code> and <code>except</code> blocks. Then use a <code>finally</code> block to print 'All Done.'

# %%
x = 5
y = 0

try:
    z = x/y
except ZeroDivisionError:
    print("ZeroDivisionError : You cannot divide any integer with zero")
finally:
    print("All Done")
# Out:
# ZeroDivisionError : You cannot divide any integer with zero
# All Done

# %% [markdown]
# ### Problem 3
# Write a function that asks for an integer and prints the square of it. Use a <code>while</code> loop with a <code>try</code>, <code>except</code>, <code>else</code> block to account for incorrect inputs.

# %%
def ask():
    while True:
        try:
            val = int(input("Enter any integer: "))
        except:
            print("Please enter valid integer")
            continue
        else:
            print(f"Gotcha! Square of {val} is {val*val}") 
            break

# %%
ask()
# Out:
# Enter any integer: three
# Please enter valid integer
# Enter any integer: two
# Please enter valid integer
# Enter any integer: 4
# Gotcha! Square of 4 is 16

# %% [markdown]
# # Great Job!
