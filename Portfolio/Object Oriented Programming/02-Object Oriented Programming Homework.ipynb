# %% [markdown]
# ___
#
# <a href='https://www.udemy.com/user/joseportilla/'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Content Copyright by Pierian Data</em></center>

# %% [markdown]
# # Object Oriented Programming
# ## Homework Assignment
#
# #### Problem 1
# Fill in the Line class methods to accept coordinates as a pair of tuples and return the slope and distance of the line.

# %%
class Line:
    
    def __init__(self,coor1,coor2):
        #ATTRIBUTES
        self.coor1 = coor1
        self.coor2 = coor2
    
    def distance(self):
        x1,y1 = self.coor1
        x2,y2 = self.coor2

        return ((x2 - x1)**2 + (y2 - y1)**2) ** (1/2)
     
    def slope(self):
        x1,y1 = self.coor1
        x2,y2 = self.coor2

        return (y2 - y1) / (x2 - x1)

# %%
# EXAMPLE OUTPUT

coordinate1 = (3,2)
coordinate2 = (8,10)

li = Line(coordinate1,coordinate2)

# %%
li.distance()
# Out:
# 9.433981132056603

# %%
li.slope()
# Out:
# 1.6

# %% [markdown]
# ________
# #### Problem 2

# %% [markdown]
# Fill in the class

# %%
class Cylinder:

    #GLOBAL ATTRIBUTES
    pi = 3.14
    
    def __init__(self,height=1,radius=1):

        #INITIALIZED ATTRIBUTES
        self.height = height #Default of 1
        self.radius = radius #Default of 1
        
    def volume(self):

        #Formula is [pi * radius^2 * height]
        return self.pi * (self.radius ** 2) * self.height
    
    def surface_area(self):
        
        #Formula is [2 * pi * radius * height + 2 * pi * radius^2]
        return 2 * self.pi * self.radius * self.height + 2 * self.pi * self.radius**2

# %%
# EXAMPLE OUTPUT
c = Cylinder(2,3)

# %%
c.volume()
# Out:
# 56.52

# %%
c.surface_area()
# Out:
# 94.2
