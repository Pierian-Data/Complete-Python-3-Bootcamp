# %%
'''

This is the card game War. The object of the game is for each player to draw a card from their deck, compare values, 
and the player with the higher card value places his original card, and his opponents card at the bottom of the victorious players deck (no the public deck).

Created by: Mattan Romano 6/9/2022
Last Updated: 6/12/2022

'''
# Out:
# '\n\nThis is the card game War. The object of the game is for each player to draw a card from their deck, compare values, \nand the player with the higher card value places his original card, and his opponents card at the bottom of the victorious players deck (no the public deck).\n\nCreated by: Mattan Romano 6/9/2022\nLast Updated: 6/12/2022\n\n'

# %%
#Modules to Import

import random #Used in the deck class to shuffle deck

# %%
### Card Attributes ###

# Listing out all card suites for iteration
card_suites = ['Hearts','Diamonds','Clubs','Spades']

# Listing out all card name for iteration
card_name = ['Two','Three','Four','Five','Six','Seven','Eight','Nine','Ten','Jack','Queen','King','Ace']

# Listing out all card values for ito determine who wins round/WAR situation
card_value = {'Two':2, 'Three':3,'Four':4,'Five':5,'Six':6,'Seven':7,'Eight':8,'Nine':9,'Ten':10,'Jack':11,'Queen':12,'King':13,'Ace':14}

# %%
class Card():

    # Creation requires card name & suite
    def __init__ (self,name:str,suite:str):
        
        # Attributes
        self.name = name
        self.suite = suite
        self.value = card_value.get(self.name)


    def __str__ (self):

        return f"{self.name} of {self.suite}"

# %%
class Deck():
       
    def __init__ (self):

        # Attributes
        self.card_list = [] # Create empty list upon creation. Will iterate through names/suites to create Card objects for each pair

        # Loop through each card name/suite combination and create a card object
        for suite in card_suites:

            for name in card_name:
                   
                created_card = Card(name,suite)

                # Append created card to list - length should be 52
                self.card_list.append(created_card)

                
    def shuffle (self):

         # Shuffle the deck so that it is in random order to make it game ready. The shuffle is an in place action so no new list is needed
        try:
            random.shuffle(self.card_list)
        except  :
            print("Shuffle not succesful")
        else:    
            print("The deck has been shuffled\n")

    
    def remove_card (self):

        # Remove card from top of deck
        return self.card_list.pop(0)

    def clear_deck (self):

        # Clears all cards from deck
        self.card_list.clear()
        print(f"Deck has been cleared. Length is: {self.length}\n")


    def __len__ (self):

        # Determine length of the list/deck
        return len(self.card_list)

# %%
class Player():

    def __init__ (self,name:str,turn_number:int):

        # Attributes
        self.name = name
        self.player_turn = turn_number
        self.player_deck = []
        
    def add_card (self,card:Card):

        # Append a card object to the player list
        self.player_deck.append(card)

    def remove_card (self):

        # Remove a card object from the top players list
        removed_card = self.player_deck.pop(0)
        return removed_card
       
    def clear_deck (self):

        # Removes all cards from the deck
        self.player_deck.clear()

    def __len__ (self):
    
        # Determine length of the list/deck
        return len(self.player_deck)

# %%
# GAME START
print("The Game Is About To Start\n")
print("..........................")
# Out:
# The Game Is About To Start
#
# ..........................

# %%
print("First we need to establish who is playing the game.\n")

# Player One section
print("Can the first player enter their name\n")
player_1_name = input("Player One what is your name?\n")
player_1 = Player(player_1_name,1)
print(f"Thank you for that {player_1_name}\n")


# Player Two section
print("Can the second player enter their name\n")
player_2_name = input("Player Two what is your name?\n")
player_2 = Player(player_2_name,2)
print(f"Thank you for that {player_2_name}\n")
# Out:
# First we need to establish who is playing the game.
#
# Can the first player enter their name
#
# Thank you for that Mattan
#
# Can the second player enter their name
#
# Thank you for that Torrey

# %%
# Building the deck
print("Let's create a game deck in order to start playing.\n")
game_deck = Deck()

# Shuffling the deck 10 times to ensure sufficent shuffle
for shuffle in range (10):
    game_deck.shuffle()

# Checking to see if deck is 52 cards
try:
    if len(game_deck) == 52:
      print("We are now ready to start the game.\n")
      print("Each player will have 7 cards dealt.\n")
except:
    print("Deck is not 52 cards. Error with deck creation.")
    

# Ensuring the players don't already have cards in the deck on reboot of game
player_1.clear_deck()
player_2.clear_deck()
# Out:
# Let's create a game deck in order to start playing.
#
# The deck has been shuffled
#
# The deck has been shuffled
#
# The deck has been shuffled
#
# The deck has been shuffled
#
# The deck has been shuffled
#
# The deck has been shuffled
#
# The deck has been shuffled
#
# The deck has been shuffled
#
# The deck has been shuffled
#
# The deck has been shuffled
#
# We are now ready to start the game.
#
# Each player will have 7 cards dealt.

# %%
print(len(player_1))
print(len(player_2))
print(len(game_deck))
# Out:
# 0
# 0
# 52

# %%
# Dealing 26 cards to Players One
while len(player_1) < 26:
    try:
        player_1.add_card(game_deck.remove_card())
              
    except:
        print("Unable to remove card from deck. Confirm that there are cards in the deck.\n")    

# Dealing 26 cards to Players Two
while len(player_2) < 26:
    try:
        player_2.add_card(game_deck.remove_card())
    except:
        print("Unable to remove card from deck. Confirm that there are cards in the deck.\n")

# %%
print(len(player_1))
print(len(player_2))
print(len(game_deck))
# Out:
# 26
# 26
# 0

# %%
# Game can only exist while the players have cards
for round in range (1,101):

    print(f"-------- START OF ROUND: {round}\n")

    print(f"{player_1.name} and {player_2.name} be ready to show your cards!")
    print(f"{player_1.name} deck length:",len(player_1))
    print(f"{player_2.name} deck length:",len(player_2))


    # Removing card from each players deck
    print('\n')
    player_1_card = player_1.remove_card()
    player_2_card = player_2.remove_card()

    print(f"{player_1.name} presents: {player_1_card}\n{player_2.name} presents: {player_2_card}")
   

    #Comparing player card values
    if player_1_card.value > player_2_card.value:
        print('\n')
        print(f"{player_1.name} wins!")
        war_situation = False

        player_1.add_card(player_1_card)
        player_1.add_card(player_2_card)
        
        print(f"{player_1.name} deck length:",len(player_1))
        print(f"{player_2.name} deck length:",len(player_2))
        print('\n')

    elif player_1_card.value == player_2_card.value:
        print('\n')
        print("WAR WAR WAR WAR WAR WAR WAR WAR")

        war_situation = True
        player_1_war_card = player_1_card
        player_2_war_card = player_2_card
        print('\n')

    else:
        print('\n')
        print(f"{player_2.name} wins!")
        war_situation = False

        player_2.add_card(player_1_card)
        player_2.add_card(player_2_card)

        print(f"{player_1.name} deck length:",len(player_1))
        print(f"{player_2.name} deck length:",len(player_2))
        print('\n')



    while war_situation == True:
           
        print(f"{player_1.name} and {player_2.name} be ready to show your war cards!")
        print(f"{player_1.name} deck length:",len(player_1))
        print(f"{player_2.name} deck length:",len(player_2))


        # Removing card from each players deck
        player_1_card = player_1.remove_card()
        player_2_card = player_2.remove_card()

        print(f"{player_1.name} presents: {player_1_card}\n{player_2.name} presents: {player_2_card}")
        print(f"{player_1.name} deck length:",len(player_1))
        print(f"{player_2.name} deck length:",len(player_2))

        #Comparing player card values
        if player_1_card.value > player_2_card.value:
            print('\n')
            print(f"{player_1.name} wins!")
            war_situation = False
            
            player_1.add_card(player_1_card)
            player_1.add_card(player_2_card)
            player_1.add_card(player_1_war_card)
            player_1.add_card(player_2_war_card)

            print("Added the following cards",player_1_card,player_2_card,player_1_war_card,player_2_war_card)

            print(f"{player_1.name} deck length:",len(player_1))
            print(f"{player_2.name} deck length:",len(player_2))
            print('\n')
            print('\n')
            break


        elif player_1_card.value == player_2_card.value:
            print('\n')
            print("WAR WAR WAR WAR WAR WAR WAR WAR")

            war_situation = True
            print('\n')

        else:
            print('\n')
            print(f"{player_2.name} wins!")
            war_situation = False

            player_2.add_card(player_1_card)
            player_2.add_card(player_2_card)
            player_2.add_card(player_1_war_card)
            player_2.add_card(player_2_war_card)

            print(f"{player_1.name} deck length:",len(player_1))
            print(f"{player_2.name} deck length:",len(player_2))
            print('\n')          
            print('\n')
            break









    print(f"-------- END OF ROUND: {round}\n")
# Out:
# -------- START OF ROUND: 1
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# Mattan presents: Ten of Diamonds
# Torrey presents: Eight of Spades
#
#
# Mattan wins!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# -------- END OF ROUND: 1
#
# -------- START OF ROUND: 2
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# Mattan presents: Two of Hearts
# Torrey presents: Jack of Diamonds
#
#
# Torrey wins!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# -------- END OF ROUND: 2
#
# -------- START OF ROUND: 3
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# Mattan presents: Jack of Hearts
# Torrey presents: Six of Spades
#
#
# Mattan wins!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# -------- END OF ROUND: 3
#
# -------- START OF ROUND: 4
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# Mattan presents: Four of Diamonds
# Torrey presents: Ten of Clubs
#
#
# Torrey wins!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# -------- END OF ROUND: 4
#
# -------- START OF ROUND: 5
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# Mattan presents: Queen of Diamonds
# Torrey presents: Three of Diamonds
#
#
# Mattan wins!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# -------- END OF ROUND: 5
#
# -------- START OF ROUND: 6
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# Mattan presents: Three of Spades
# Torrey presents: King of Hearts
#
#
# Torrey wins!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# -------- END OF ROUND: 6
#
# -------- START OF ROUND: 7
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# Mattan presents: Ace of Spades
# Torrey presents: Six of Hearts
#
#
# Mattan wins!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# -------- END OF ROUND: 7
#
# -------- START OF ROUND: 8
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# Mattan presents: Two of Diamonds
# Torrey presents: Ten of Spades
#
#
# Torrey wins!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# -------- END OF ROUND: 8
#
# -------- START OF ROUND: 9
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# Mattan presents: Seven of Diamonds
# Torrey presents: Eight of Diamonds
#
#
# Torrey wins!
# Mattan deck length: 21
# Torrey deck length: 31
#
#
# -------- END OF ROUND: 9
#
# -------- START OF ROUND: 10
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 21
# Torrey deck length: 31
#
#
# Mattan presents: Five of Hearts
# Torrey presents: King of Clubs
#
#
# Torrey wins!
# Mattan deck length: 20
# Torrey deck length: 32
#
#
# -------- END OF ROUND: 10
#
# -------- START OF ROUND: 11
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 20
# Torrey deck length: 32
#
#
# Mattan presents: Ace of Hearts
# Torrey presents: Five of Diamonds
#
#
# Mattan wins!
# Mattan deck length: 21
# Torrey deck length: 31
#
#
# -------- END OF ROUND: 11
#
# -------- START OF ROUND: 12
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 21
# Torrey deck length: 31
#
#
# Mattan presents: Eight of Hearts
# Torrey presents: Seven of Clubs
#
#
# Mattan wins!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# -------- END OF ROUND: 12
#
# -------- START OF ROUND: 13
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# Mattan presents: Ace of Diamonds
# Torrey presents: Three of Hearts
#
#
# Mattan wins!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# -------- END OF ROUND: 13
#
# -------- START OF ROUND: 14
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# Mattan presents: Nine of Diamonds
# Torrey presents: King of Diamonds
#
#
# Torrey wins!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# -------- END OF ROUND: 14
#
# -------- START OF ROUND: 15
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# Mattan presents: Jack of Spades
# Torrey presents: Seven of Hearts
#
#
# Mattan wins!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# -------- END OF ROUND: 15
#
# -------- START OF ROUND: 16
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# Mattan presents: Three of Clubs
# Torrey presents: Ten of Hearts
#
#
# Torrey wins!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# -------- END OF ROUND: 16
#
# -------- START OF ROUND: 17
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# Mattan presents: Queen of Clubs
# Torrey presents: Two of Spades
#
#
# Mattan wins!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# -------- END OF ROUND: 17
#
# -------- START OF ROUND: 18
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# Mattan presents: Four of Clubs
# Torrey presents: Eight of Clubs
#
#
# Torrey wins!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# -------- END OF ROUND: 18
#
# -------- START OF ROUND: 19
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# Mattan presents: Nine of Spades
# Torrey presents: Two of Clubs
#
#
# Mattan wins!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# -------- END OF ROUND: 19
#
# -------- START OF ROUND: 20
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# Mattan presents: Five of Clubs
# Torrey presents: King of Spades
#
#
# Torrey wins!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# -------- END OF ROUND: 20
#
# -------- START OF ROUND: 21
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# Mattan presents: Queen of Spades
# Torrey presents: Five of Spades
#
#
# Mattan wins!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# -------- END OF ROUND: 21
#
# -------- START OF ROUND: 22
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# Mattan presents: Four of Spades
# Torrey presents: Jack of Clubs
#
#
# Torrey wins!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# -------- END OF ROUND: 22
#
# -------- START OF ROUND: 23
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# Mattan presents: Ten of Diamonds
# Torrey presents: Nine of Clubs
#
#
# Mattan wins!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# -------- END OF ROUND: 23
#
# -------- START OF ROUND: 24
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# Mattan presents: Eight of Spades
# Torrey presents: Ace of Clubs
#
#
# Torrey wins!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# -------- END OF ROUND: 24
#
# -------- START OF ROUND: 25
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# Mattan presents: Jack of Hearts
# Torrey presents: Four of Hearts
#
#
# Mattan wins!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# -------- END OF ROUND: 25
#
# -------- START OF ROUND: 26
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# Mattan presents: Six of Spades
# Torrey presents: Seven of Spades
#
#
# Torrey wins!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# -------- END OF ROUND: 26
#
# -------- START OF ROUND: 27
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# Mattan presents: Queen of Diamonds
# Torrey presents: Six of Diamonds
#
#
# Mattan wins!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# -------- END OF ROUND: 27
#
# -------- START OF ROUND: 28
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# Mattan presents: Three of Diamonds
# Torrey presents: Queen of Hearts
#
#
# Torrey wins!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# -------- END OF ROUND: 28
#
# -------- START OF ROUND: 29
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# Mattan presents: Ace of Spades
# Torrey presents: Six of Clubs
#
#
# Mattan wins!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# -------- END OF ROUND: 29
#
# -------- START OF ROUND: 30
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# Mattan presents: Six of Hearts
# Torrey presents: Nine of Hearts
#
#
# Torrey wins!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# -------- END OF ROUND: 30
#
# -------- START OF ROUND: 31
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# Mattan presents: Ace of Hearts
# Torrey presents: Two of Hearts
#
#
# Mattan wins!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# -------- END OF ROUND: 31
#
# -------- START OF ROUND: 32
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# Mattan presents: Five of Diamonds
# Torrey presents: Jack of Diamonds
#
#
# Torrey wins!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# -------- END OF ROUND: 32
#
# -------- START OF ROUND: 33
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# Mattan presents: Eight of Hearts
# Torrey presents: Four of Diamonds
#
#
# Mattan wins!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# -------- END OF ROUND: 33
#
# -------- START OF ROUND: 34
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# Mattan presents: Seven of Clubs
# Torrey presents: Ten of Clubs
#
#
# Torrey wins!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# -------- END OF ROUND: 34
#
# -------- START OF ROUND: 35
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# Mattan presents: Ace of Diamonds
# Torrey presents: Three of Spades
#
#
# Mattan wins!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# -------- END OF ROUND: 35
#
# -------- START OF ROUND: 36
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# Mattan presents: Three of Hearts
# Torrey presents: King of Hearts
#
#
# Torrey wins!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# -------- END OF ROUND: 36
#
# -------- START OF ROUND: 37
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# Mattan presents: Jack of Spades
# Torrey presents: Two of Diamonds
#
#
# Mattan wins!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# -------- END OF ROUND: 37
#
# -------- START OF ROUND: 38
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# Mattan presents: Seven of Hearts
# Torrey presents: Ten of Spades
#
#
# Torrey wins!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# -------- END OF ROUND: 38
#
# -------- START OF ROUND: 39
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# Mattan presents: Queen of Clubs
# Torrey presents: Seven of Diamonds
#
#
# Mattan wins!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# -------- END OF ROUND: 39
#
# -------- START OF ROUND: 40
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# Mattan presents: Two of Spades
# Torrey presents: Eight of Diamonds
#
#
# Torrey wins!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# -------- END OF ROUND: 40
#
# -------- START OF ROUND: 41
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# Mattan presents: Nine of Spades
# Torrey presents: Five of Hearts
#
#
# Mattan wins!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# -------- END OF ROUND: 41
#
# -------- START OF ROUND: 42
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# Mattan presents: Two of Clubs
# Torrey presents: King of Clubs
#
#
# Torrey wins!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# -------- END OF ROUND: 42
#
# -------- START OF ROUND: 43
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# Mattan presents: Queen of Spades
# Torrey presents: Nine of Diamonds
#
#
# Mattan wins!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# -------- END OF ROUND: 43
#
# -------- START OF ROUND: 44
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# Mattan presents: Five of Spades
# Torrey presents: King of Diamonds
#
#
# Torrey wins!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# -------- END OF ROUND: 44
#
# -------- START OF ROUND: 45
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# Mattan presents: Ten of Diamonds
# Torrey presents: Three of Clubs
#
#
# Mattan wins!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# -------- END OF ROUND: 45
#
# -------- START OF ROUND: 46
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# Mattan presents: Nine of Clubs
# Torrey presents: Ten of Hearts
#
#
# Torrey wins!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# -------- END OF ROUND: 46
#
# -------- START OF ROUND: 47
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# Mattan presents: Jack of Hearts
# Torrey presents: Four of Clubs
#
#
# Mattan wins!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# -------- END OF ROUND: 47
#
# -------- START OF ROUND: 48
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# Mattan presents: Four of Hearts
# Torrey presents: Eight of Clubs
#
#
# Torrey wins!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# -------- END OF ROUND: 48
#
# -------- START OF ROUND: 49
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# Mattan presents: Queen of Diamonds
# Torrey presents: Five of Clubs
#
#
# Mattan wins!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# -------- END OF ROUND: 49
#
# -------- START OF ROUND: 50
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# Mattan presents: Six of Diamonds
# Torrey presents: King of Spades
#
#
# Torrey wins!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# -------- END OF ROUND: 50
#
# -------- START OF ROUND: 51
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# Mattan presents: Ace of Spades
# Torrey presents: Four of Spades
#
#
# Mattan wins!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# -------- END OF ROUND: 51
#
# -------- START OF ROUND: 52
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# Mattan presents: Six of Clubs
# Torrey presents: Jack of Clubs
#
#
# Torrey wins!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# -------- END OF ROUND: 52
#
# -------- START OF ROUND: 53
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# Mattan presents: Ace of Hearts
# Torrey presents: Eight of Spades
#
#
# Mattan wins!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# -------- END OF ROUND: 53
#
# -------- START OF ROUND: 54
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# Mattan presents: Two of Hearts
# Torrey presents: Ace of Clubs
#
#
# Torrey wins!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# -------- END OF ROUND: 54
#
# -------- START OF ROUND: 55
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# Mattan presents: Eight of Hearts
# Torrey presents: Six of Spades
#
#
# Mattan wins!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# -------- END OF ROUND: 55
#
# -------- START OF ROUND: 56
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# Mattan presents: Four of Diamonds
# Torrey presents: Seven of Spades
#
#
# Torrey wins!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# -------- END OF ROUND: 56
#
# -------- START OF ROUND: 57
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# Mattan presents: Ace of Diamonds
# Torrey presents: Three of Diamonds
#
#
# Mattan wins!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# -------- END OF ROUND: 57
#
# -------- START OF ROUND: 58
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# Mattan presents: Three of Spades
# Torrey presents: Queen of Hearts
#
#
# Torrey wins!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# -------- END OF ROUND: 58
#
# -------- START OF ROUND: 59
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# Mattan presents: Jack of Spades
# Torrey presents: Six of Hearts
#
#
# Mattan wins!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# -------- END OF ROUND: 59
#
# -------- START OF ROUND: 60
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# Mattan presents: Two of Diamonds
# Torrey presents: Nine of Hearts
#
#
# Torrey wins!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# -------- END OF ROUND: 60
#
# -------- START OF ROUND: 61
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# Mattan presents: Queen of Clubs
# Torrey presents: Five of Diamonds
#
#
# Mattan wins!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# -------- END OF ROUND: 61
#
# -------- START OF ROUND: 62
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# Mattan presents: Seven of Diamonds
# Torrey presents: Jack of Diamonds
#
#
# Torrey wins!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# -------- END OF ROUND: 62
#
# -------- START OF ROUND: 63
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# Mattan presents: Nine of Spades
# Torrey presents: Seven of Clubs
#
#
# Mattan wins!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# -------- END OF ROUND: 63
#
# -------- START OF ROUND: 64
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# Mattan presents: Five of Hearts
# Torrey presents: Ten of Clubs
#
#
# Torrey wins!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# -------- END OF ROUND: 64
#
# -------- START OF ROUND: 65
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# Mattan presents: Queen of Spades
# Torrey presents: Three of Hearts
#
#
# Mattan wins!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# -------- END OF ROUND: 65
#
# -------- START OF ROUND: 66
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# Mattan presents: Nine of Diamonds
# Torrey presents: King of Hearts
#
#
# Torrey wins!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# -------- END OF ROUND: 66
#
# -------- START OF ROUND: 67
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# Mattan presents: Ten of Diamonds
# Torrey presents: Seven of Hearts
#
#
# Mattan wins!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# -------- END OF ROUND: 67
#
# -------- START OF ROUND: 68
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# Mattan presents: Three of Clubs
# Torrey presents: Ten of Spades
#
#
# Torrey wins!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# -------- END OF ROUND: 68
#
# -------- START OF ROUND: 69
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# Mattan presents: Jack of Hearts
# Torrey presents: Two of Spades
#
#
# Mattan wins!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# -------- END OF ROUND: 69
#
# -------- START OF ROUND: 70
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# Mattan presents: Four of Clubs
# Torrey presents: Eight of Diamonds
#
#
# Torrey wins!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# -------- END OF ROUND: 70
#
# -------- START OF ROUND: 71
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# Mattan presents: Queen of Diamonds
# Torrey presents: Two of Clubs
#
#
# Mattan wins!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# -------- END OF ROUND: 71
#
# -------- START OF ROUND: 72
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# Mattan presents: Five of Clubs
# Torrey presents: King of Clubs
#
#
# Torrey wins!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# -------- END OF ROUND: 72
#
# -------- START OF ROUND: 73
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# Mattan presents: Ace of Spades
# Torrey presents: Five of Spades
#
#
# Mattan wins!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# -------- END OF ROUND: 73
#
# -------- START OF ROUND: 74
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# Mattan presents: Four of Spades
# Torrey presents: King of Diamonds
#
#
# Torrey wins!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# -------- END OF ROUND: 74
#
# -------- START OF ROUND: 75
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# Mattan presents: Ace of Hearts
# Torrey presents: Nine of Clubs
#
#
# Mattan wins!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# -------- END OF ROUND: 75
#
# -------- START OF ROUND: 76
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# Mattan presents: Eight of Spades
# Torrey presents: Ten of Hearts
#
#
# Torrey wins!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# -------- END OF ROUND: 76
#
# -------- START OF ROUND: 77
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# Mattan presents: Eight of Hearts
# Torrey presents: Four of Hearts
#
#
# Mattan wins!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# -------- END OF ROUND: 77
#
# -------- START OF ROUND: 78
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# Mattan presents: Six of Spades
# Torrey presents: Eight of Clubs
#
#
# Torrey wins!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# -------- END OF ROUND: 78
#
# -------- START OF ROUND: 79
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# Mattan presents: Ace of Diamonds
# Torrey presents: Six of Diamonds
#
#
# Mattan wins!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# -------- END OF ROUND: 79
#
# -------- START OF ROUND: 80
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# Mattan presents: Three of Diamonds
# Torrey presents: King of Spades
#
#
# Torrey wins!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# -------- END OF ROUND: 80
#
# -------- START OF ROUND: 81
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# Mattan presents: Jack of Spades
# Torrey presents: Six of Clubs
#
#
# Mattan wins!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# -------- END OF ROUND: 81
#
# -------- START OF ROUND: 82
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# Mattan presents: Six of Hearts
# Torrey presents: Jack of Clubs
#
#
# Torrey wins!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# -------- END OF ROUND: 82
#
# -------- START OF ROUND: 83
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# Mattan presents: Queen of Clubs
# Torrey presents: Two of Hearts
#
#
# Mattan wins!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# -------- END OF ROUND: 83
#
# -------- START OF ROUND: 84
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# Mattan presents: Five of Diamonds
# Torrey presents: Ace of Clubs
#
#
# Torrey wins!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# -------- END OF ROUND: 84
#
# -------- START OF ROUND: 85
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 22
# Torrey deck length: 30
#
#
# Mattan presents: Nine of Spades
# Torrey presents: Four of Diamonds
#
#
# Mattan wins!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# -------- END OF ROUND: 85
#
# -------- START OF ROUND: 86
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 23
# Torrey deck length: 29
#
#
# Mattan presents: Seven of Clubs
# Torrey presents: Seven of Spades
#
#
# WAR WAR WAR WAR WAR WAR WAR WAR
#
#
# Mattan and Torrey be ready to show your war cards!
# Mattan deck length: 22
# Torrey deck length: 28
# Mattan presents: Queen of Spades
# Torrey presents: Three of Spades
# Mattan deck length: 21
# Torrey deck length: 27
#
#
# Mattan wins!
# Mattan deck length: 25
# Torrey deck length: 27
#
#
#
#
# -------- END OF ROUND: 86
#
# -------- START OF ROUND: 87
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 25
# Torrey deck length: 27
#
#
# Mattan presents: Three of Hearts
# Torrey presents: Queen of Hearts
#
#
# Torrey wins!
# Mattan deck length: 24
# Torrey deck length: 28
#
#
# -------- END OF ROUND: 87
#
# -------- START OF ROUND: 88
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 24
# Torrey deck length: 28
#
#
# Mattan presents: Ten of Diamonds
# Torrey presents: Two of Diamonds
#
#
# Mattan wins!
# Mattan deck length: 25
# Torrey deck length: 27
#
#
# -------- END OF ROUND: 88
#
# -------- START OF ROUND: 89
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 25
# Torrey deck length: 27
#
#
# Mattan presents: Seven of Hearts
# Torrey presents: Nine of Hearts
#
#
# Torrey wins!
# Mattan deck length: 24
# Torrey deck length: 28
#
#
# -------- END OF ROUND: 89
#
# -------- START OF ROUND: 90
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 24
# Torrey deck length: 28
#
#
# Mattan presents: Jack of Hearts
# Torrey presents: Seven of Diamonds
#
#
# Mattan wins!
# Mattan deck length: 25
# Torrey deck length: 27
#
#
# -------- END OF ROUND: 90
#
# -------- START OF ROUND: 91
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 25
# Torrey deck length: 27
#
#
# Mattan presents: Two of Spades
# Torrey presents: Jack of Diamonds
#
#
# Torrey wins!
# Mattan deck length: 24
# Torrey deck length: 28
#
#
# -------- END OF ROUND: 91
#
# -------- START OF ROUND: 92
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 24
# Torrey deck length: 28
#
#
# Mattan presents: Queen of Diamonds
# Torrey presents: Five of Hearts
#
#
# Mattan wins!
# Mattan deck length: 25
# Torrey deck length: 27
#
#
# -------- END OF ROUND: 92
#
# -------- START OF ROUND: 93
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 25
# Torrey deck length: 27
#
#
# Mattan presents: Two of Clubs
# Torrey presents: Ten of Clubs
#
#
# Torrey wins!
# Mattan deck length: 24
# Torrey deck length: 28
#
#
# -------- END OF ROUND: 93
#
# -------- START OF ROUND: 94
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 24
# Torrey deck length: 28
#
#
# Mattan presents: Ace of Spades
# Torrey presents: Nine of Diamonds
#
#
# Mattan wins!
# Mattan deck length: 25
# Torrey deck length: 27
#
#
# -------- END OF ROUND: 94
#
# -------- START OF ROUND: 95
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 25
# Torrey deck length: 27
#
#
# Mattan presents: Five of Spades
# Torrey presents: King of Hearts
#
#
# Torrey wins!
# Mattan deck length: 24
# Torrey deck length: 28
#
#
# -------- END OF ROUND: 95
#
# -------- START OF ROUND: 96
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 24
# Torrey deck length: 28
#
#
# Mattan presents: Ace of Hearts
# Torrey presents: Three of Clubs
#
#
# Mattan wins!
# Mattan deck length: 25
# Torrey deck length: 27
#
#
# -------- END OF ROUND: 96
#
# -------- START OF ROUND: 97
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 25
# Torrey deck length: 27
#
#
# Mattan presents: Nine of Clubs
# Torrey presents: Ten of Spades
#
#
# Torrey wins!
# Mattan deck length: 24
# Torrey deck length: 28
#
#
# -------- END OF ROUND: 97
#
# -------- START OF ROUND: 98
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 24
# Torrey deck length: 28
#
#
# Mattan presents: Eight of Hearts
# Torrey presents: Four of Clubs
#
#
# Mattan wins!
# Mattan deck length: 25
# Torrey deck length: 27
#
#
# -------- END OF ROUND: 98
#
# -------- START OF ROUND: 99
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 25
# Torrey deck length: 27
#
#
# Mattan presents: Four of Hearts
# Torrey presents: Eight of Diamonds
#
#
# Torrey wins!
# Mattan deck length: 24
# Torrey deck length: 28
#
#
# -------- END OF ROUND: 99
#
# -------- START OF ROUND: 100
#
# Mattan and Torrey be ready to show your cards!
# Mattan deck length: 24
# Torrey deck length: 28
#
#
# Mattan presents: Ace of Diamonds
# Torrey presents: Five of Clubs
#
#
# Mattan wins!
# Mattan deck length: 25
# Torrey deck length: 27
#
#
# -------- END OF ROUND: 100
