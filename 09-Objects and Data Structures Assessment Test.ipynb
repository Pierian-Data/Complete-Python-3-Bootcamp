# %% [markdown]
# # Objects and Data Structures Assessment Test

# %% [markdown]
# ## Test your knowledge.
#
# ** Answer the following questions **

# %% [markdown]
# Write a brief description of all the following Object Types and Data Structures we've learned about:

# %% [markdown]
# Numbers: objets essentiellement de 2 types : integer et float
#
# Strings: objets composés de listes de caractères indexables mais non imutable (on ne peut pas remplacer un caractère par un autre directement une fois déclarés. Se déclare à l'intérieur de guillemets simples ou doubles selon le souhait ou qu'il y a des guillements simple à l'intérieur de la chaine de caractère
#
# Lists: objets composés d'ensemble d'éléments de types différents, imbricables et qui se déclare à l'intérieur de crochets. Comme les string ils sont indexables mais mutables (on peut réassigner un élément de la liste)
#
# Tuples: collection d'éléments de types différents, indexables, non ordonnables ? (ne suis plus sure)
#
# Dictionaries: collection d'éléments indexables à partir de mots clés, qui se déclarent avec des accolades et dont les mot clés sont obligatoirement des chaines de caractère. Les valeurs peuvent être de types différents

# %% [markdown]
# ## Numbers
#
# Write an equation that uses multiplication, division, an exponent, addition, and subtraction that is equal to 100.25.
#
# Hint: This is just to test your memory of the basic arithmetic commands, work backwards from 100.25

# %%
(10**2+0.25)*(4-3)
# Out:
# 100.25

# %% [markdown]
# Answer these 3 questions without typing code. Then type code to check your answer.
#
#     What is the value of the expression 4 * (6 + 5)
#
#     What is the value of the expression 4 * 6 + 5
#
#     What is the value of the expression 4 + 6 * 5

# %%
4 + 6 * 5
# Out:
# 34

# %% [markdown]
# What is the *type* of the result of the expression 3 + 1.5 + 4?<br>float<br>

# %% [markdown]
# What would you use to find a number’s square root, as well as its square?
#
# # Square root: fonction sqrt() => nécessite d'importer au préalable le module math ou **0.5

# %% [markdown]
# # Square: operateur double étoile **2

# %% [markdown]
# ## Strings

# %% [markdown]
# Given the string 'hello' give an index command that returns 'e'. Enter your code in the cell below:

# %%
s = 'hello'
# Print out 'e' using indexing
print(s[1])
# Out:
# e

# %% [markdown]
# Reverse the string 'hello' using slicing:

# %%
s ='hello'
# Reverse the string using slicing

print(s[::-1])
# Out:
# olleh

# %% [markdown]
# Given the string hello, give two methods of producing the letter 'o' using indexing.

# %%
s ='hello'
# Print out the 'o'

# Method 1:

print(s[4])
# Out:
# o

# %%
# Method 2:

print(s[-1])
# Out:
# o

# %% [markdown]
# ## Lists

# %% [markdown]
# Build this list [0,0,0] two separate ways.

# %%
# Method 1:
liste1=[0,0]
liste2=[0]
print(liste1+liste2)
# Out:
# [0, 0, 0]

# %%
# Method 2:
liste=[0,0,0]
print(liste)
# Out:
# [0, 0, 0]

# %% [markdown]
# Reassign 'hello' in this nested list to say 'goodbye' instead:

# %%
list3 = [1,2,[3,4,'hello']]
list3[2][2]='goodbye'
print (list3)
# Out:
# [1, 2, [3, 4, 'goodbye']]

# %% [markdown]
# Sort the list below:

# %%
list4 = [5,3,4,6,1]
list4.sort()
print(list4)
# Out:
# [1, 3, 4, 5, 6]

# %% [markdown]
# ## Dictionaries

# %% [markdown]
# Using keys and indexing, grab the 'hello' from the following dictionaries:

# %%
d = {'simple_key':'hello'}
# Grab 'hello'
print(d['simple_key'])
# Out:
# hello

# %%
d = {'k1':{'k2':'hello'}}
# Grab 'hello'
print(d['k1']['k2'])
# Out:
# hello

# %%
# Getting a little tricker
d = {'k1':[{'nest_key':['this is deep',['hello']]}]}

#Grab hello
print(d['k1'][0]['nest_key'][1][0])
# Out:
# hello

# %%
# This will be hard and annoying!
d = {'k1':[1,2,{'k2':['this is tricky',{'tough':[1,2,['hello']]}]}]}

#I grabbed hello!!!
print(d['k1'][2]['k2'][1]['tough'][2][0])
# Out:
# hello

# %% [markdown]
# Can you sort a dictionary? Why or why not? Dictionnaries can't be sorted because of the type which is not done for that, done to find elements with natural langage, why would you sort them?!? (they are mappings)

# %% [markdown]
# ## Tuples

# %% [markdown]
# What is the major difference between tuples and lists?<b>tuples are lists that are immutable?!? not so sure (yes)</b>

# %% [markdown]
# How do you create a tuple? to make sure that no one can modfied them at any moment of the code (how not why...) t=(1,2,3)

# %% [markdown]
# ## Sets

# %% [markdown]
# What is unique about a set? a set contains a list of unique elements

# %% [markdown]
# Use a set to find the unique values of the list below:

# %%
list5 = [1,2,2,33,4,4,11,22,3,3,2]


print(set(list5))
# Out:
# {1, 2, 33, 4, 3, 11, 22}

# %% [markdown]
# ## Booleans

# %% [markdown]
# For the following quiz questions, we will get a preview of comparison operators. In the table below, a=3 and b=4.
#
# <table class="table table-bordered">
# <tr>
# <th style="width:10%">Operator</th><th style="width:45%">Description</th><th>Example</th>
# </tr>
# <tr>
# <td>==</td>
# <td>If the values of two operands are equal, then the condition becomes true.</td>
# <td> (a == b) is not true.</td>
# </tr>
# <tr>
# <td>!=</td>
# <td>If values of two operands are not equal, then condition becomes true.</td>
# <td> (a != b) is true.</td>
# </tr>
# <tr>
# <td>&gt;</td>
# <td>If the value of left operand is greater than the value of right operand, then condition becomes true.</td>
# <td> (a &gt; b) is not true.</td>
# </tr>
# <tr>
# <td>&lt;</td>
# <td>If the value of left operand is less than the value of right operand, then condition becomes true.</td>
# <td> (a &lt; b) is true.</td>
# </tr>
# <tr>
# <td>&gt;=</td>
# <td>If the value of left operand is greater than or equal to the value of right operand, then condition becomes true.</td>
# <td> (a &gt;= b) is not true. </td>
# </tr>
# <tr>
# <td>&lt;=</td>
# <td>If the value of left operand is less than or equal to the value of right operand, then condition becomes true.</td>
# <td> (a &lt;= b) is true. </td>
# </tr>
# </table>

# %% [markdown]
# What will be the resulting Boolean of the following pieces of code (answer fist then check by typing it in!)

# %%
# Answer before running cell
2 > 3
# Out:
# False

# %%
# Answer before running cell
3 <= 2
# Out:
# False

# %%
# Answer before running cell
3 == 2.0
# Out:
# False

# %%
# Answer before running cell
3.0 == 3
# Out:
# True

# %%
# Answer before running cell
4**0.5 != 2
# Out:
# False

# %% [markdown]
# Final Question: What is the boolean output of the cell block below?

# %%
# two nested lists
l_one = [1,2,[3,4]]
l_two = [1,2,{'k1':4}]

# True or False?
l_one[2][0] >= l_two[2]['k1']
# Out:
# False

# %% [markdown]
# ## Great Job on your first assessment!
